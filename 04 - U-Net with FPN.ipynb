# %% [markdown]
# # Libraries

# %%
# System Libraries
import os
import glob
import numpy as np
import pandas as pd

# Data Visualization
import matplotlib.pyplot as plt
import seaborn as sns
sns.set_style('darkgrid')
import graphviz
from IPython.display import Image

# Metrics and Preprocessing
import cv2
from sklearn.utils import shuffle
from sklearn.preprocessing import LabelEncoder
from sklearn.model_selection import train_test_split
import sklearn.metrics as skmetrics
from sklearn.metrics import jaccard_score, f1_score

# Deep Learning Libraries
import tensorflow as tf
from tensorflow.keras import backend as K
from tensorflow.keras import mixed_precision
from tensorflow.keras.utils import to_categorical
from tensorflow.keras.models import Model
from tensorflow.keras.utils import plot_model
from tensorflow.keras.layers import (
    Add, Input, Conv2D, Conv2DTranspose, MaxPooling2D, UpSampling2D, Dropout,
    concatenate, BatchNormalization, UpSampling2D
)
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.callbacks import ReduceLROnPlateau, EarlyStopping, ModelCheckpoint

# %% [markdown]
# # Configurations

# %%
# Enable mixed precision training
# mixed_precision.set_global_policy('mixed_float16')

# Data setup
DATA_DIR = r'/kaggle/input/leukemia/Original'
MASK_DIR = r'/kaggle/input/leukemia/Segmented'
CLASSES = ['Benign', 'Early', 'Pre', 'Pro']

# Image dimensions
SIZE_X = 256
SIZE_Y = 256
CHANNELS = 3
IMG_SHAPE = (SIZE_X, SIZE_Y, CHANNELS)
N_CLASSES = 1

# Set batch size and other hyperparameters
N_FILTERS = 32
BATCH_SIZE = 32  
EPOCHS = 35  
LEARNING_RATE = 0.001
DROPOUT_RATE = 0.4
EXPERIMENT_NAME = "U-Net_FPN_Leukemia_Segmentation"

# %% [markdown]
# # Data Pre-Processing

# %%
# Load and preprocess all images and masks
images = []
masks = []

# Load and preprocess images
for class_name in CLASSES:
    class_dir = os.path.join(DATA_DIR, class_name)
    mask_class_dir = os.path.join(MASK_DIR, class_name)
    
    if not os.path.exists(class_dir) or not os.path.exists(mask_class_dir):
        continue
        
    for img_name in sorted(os.listdir(class_dir)):
        # Process image
        img_path = os.path.join(class_dir, img_name)
        mask_path = os.path.join(mask_class_dir, img_name)
        
        if not os.path.exists(mask_path):
            continue
            
        # Load and preprocess image
        img = cv2.imread(img_path, cv2.IMREAD_COLOR)
        img = cv2.resize(img, (SIZE_Y, SIZE_X))
        img = img.astype(np.float32) / 255.0
        images.append(img)
        
        # Load and preprocess mask
        mask = cv2.imread(mask_path, cv2.IMREAD_GRAYSCALE)
        mask = cv2.resize(mask, (SIZE_Y, SIZE_X), interpolation=cv2.INTER_NEAREST)
        mask = (mask > 128).astype(np.uint8)  # Binary threshold
        masks.append(mask)

images = np.array(images)
masks = np.array(masks)

# %%
# Ensure masks are binary
masks = (masks > 0).astype(np.float32)

# Add channel dimension
masks_input = np.expand_dims(masks, axis=-1)  # Shape: (num_samples, height, width, 1)

# Split dataset into train+val and test sets
X_train_val, X_test, y_train_val, y_test = train_test_split(
    images, masks_input, test_size=0.15, shuffle=True, random_state=42
)

# Calculate the proportion for validation set from the train+val data
val_size = 0.15 / (1 - 0.15)  # val_size = 0.15 / 0.85

# Split train+val into training and validation sets
X_train, X_val, y_train, y_val = train_test_split(
    X_train_val, y_train_val, test_size=val_size, random_state=42
)

# %%
# Create TensorFlow datasets
train_ds = tf.data.Dataset.from_tensor_slices((X_train, y_train))
train_ds = train_ds.shuffle(1000).batch(BATCH_SIZE)

val_ds = tf.data.Dataset.from_tensor_slices((X_val, y_val)).batch(BATCH_SIZE)
test_ds = tf.data.Dataset.from_tensor_slices((X_test, y_test)).batch(BATCH_SIZE)

# %%
# Display sample images and their corresponding masks
plt.figure(figsize=(15, 10))

# Display images
for i in range(5):
    plt.subplot(5, 5, 1 + 5 + i)
    plt.axis('off')
    plt.imshow(images[i])
    plt.title(f'Original Image {i+1}')
              
# Display masks
for i in range(5):
    plt.subplot(5, 5, 1 + i)
    plt.axis('off')
    plt.imshow(masks[i], cmap='gray')
    plt.title(f'Mask {i+1}')
    
plt.show()

# %%
# Verify data information
print(f'IMAGES:\n'
      f'Unique values: {np.unique(images)}\n'
      f'Shape: {images.shape}\n'
      f'Type: {images.dtype}\n\n'
      f'MASKS:\n'
      f'Unique values: {np.unique(masks)}\n'
      f'Shape: {masks.shape}\n'
      f'Type: {masks.dtype}')
# Out:
# IMAGES:
# Unique values: [0.         0.00392157 0.00784314 0.01176471 0.01568628 0.01960784
#  0.02352941 0.02745098 0.03137255 0.03529412 0.03921569 0.04313726
#  0.04705882 0.05098039 0.05490196 0.05882353 0.0627451  0.06666667
#  0.07058824 0.07450981 0.07843138 0.08235294 0.08627451 0.09019608
#  0.09411765 0.09803922 0.10196079 0.10588235 0.10980392 0.11372549
#  0.11764706 0.12156863 0.1254902  0.12941177 0.13333334 0.13725491
#  0.14117648 0.14509805 0.14901961 0.15294118 0.15686275 0.16078432
#  0.16470589 0.16862746 0.17254902 0.1764706  0.18039216 0.18431373
#  0.1882353  0.19215687 0.19607843 0.2        0.20392157 0.20784314
#  0.21176471 0.21568628 0.21960784 0.22352941 0.22745098 0.23137255
#  0.23529412 0.23921569 0.24313726 0.24705882 0.2509804  0.25490198
#  0.25882354 0.2627451  0.26666668 0.27058825 0.27450982 0.2784314
#  0.28235295 0.28627452 0.2901961  0.29411766 0.29803923 0.3019608
#  0.30588236 0.30980393 0.3137255  0.31764707 0.32156864 0.3254902
#  0.32941177 0.33333334 0.3372549  0.34117648 0.34509805 0.34901962
#  0.3529412  0.35686275 0.36078432 0.3647059  0.36862746 0.37254903
#  0.3764706  0.38039216 0.38431373 0.3882353  0.39215687 0.39607844
#  0.4        0.40392157 0.40784314 0.4117647  0.41568628 0.41960785
#  0.42352942 0.42745098 0.43137255 0.43529412 0.4392157  0.44313726
#  0.44705883 0.4509804  0.45490196 0.45882353 0.4627451  0.46666667
#  0.47058824 0.4745098  0.47843137 0.48235294 0.4862745  0.49019608
#  0.49411765 0.49803922 0.5019608  0.5058824  0.50980395 0.5137255
#  0.5176471  0.52156866 0.5254902  0.5294118  0.53333336 0.5372549
#  0.5411765  0.54509807 0.54901963 0.5529412  0.5568628  0.56078434
#  0.5647059  0.5686275  0.57254905 0.5764706  0.5803922  0.58431375
#  0.5882353  0.5921569  0.59607846 0.6        0.6039216  0.60784316
#  0.6117647  0.6156863  0.61960787 0.62352943 0.627451   0.6313726
#  0.63529414 0.6392157  0.6431373  0.64705884 0.6509804  0.654902
#  0.65882355 0.6627451  0.6666667  0.67058825 0.6745098  0.6784314
#  0.68235296 0.6862745  0.6901961  0.69411767 0.69803923 0.7019608
#  0.7058824  0.70980394 0.7137255  0.7176471  0.72156864 0.7254902
#  0.7294118  0.73333335 0.7372549  0.7411765  0.74509805 0.7490196
#  0.7529412  0.75686276 0.7607843  0.7647059  0.76862746 0.77254903
#  0.7764706  0.78039217 0.78431374 0.7882353  0.7921569  0.79607844
#  0.8        0.8039216  0.80784315 0.8117647  0.8156863  0.81960785
#  0.8235294  0.827451   0.83137256 0.8352941  0.8392157  0.84313726
#  0.84705883 0.8509804  0.85490197 0.85882354 0.8627451  0.8666667
#  0.87058824 0.8745098  0.8784314  0.88235295 0.8862745  0.8901961
#  0.89411765 0.8980392  0.9019608  0.90588236 0.9098039  0.9137255
#  0.91764706 0.92156863 0.9254902  0.92941177 0.93333334 0.9372549
#  0.9411765  0.94509804 0.9490196  0.9529412  0.95686275 0.9607843
#  0.9647059  0.96862745 0.972549   0.9764706  0.98039216 0.9843137
#  0.9882353  0.99215686 0.99607843 1.        ]
# Shape: (3256, 256, 256, 3)
# Type: float32
#
# MASKS:
# Unique values: [0. 1.]
# Shape: (3256, 256, 256)
# Type: float32

# %%
# Print final dataset information
print(f'Final dataset shapes:')
print(f'TRAIN SET:\n'
      f'X_train shape: {X_train.shape}\n'
      f'y_train shape: {y_train.shape}\n\n'
      f'VALIDATION SET:\n'
      f'X_val shape: {X_val.shape}\n'
      f'y_val shape: {y_val.shape}\n\n'
      f'TEST SET:\n'
      f'X_test shape: {X_test.shape}\n'
      f'y_test shape: {y_test.shape}')
# Out:
# Final dataset shapes:
# TRAIN SET:
# X_train shape: (2278, 256, 256, 3)
# y_train shape: (2278, 256, 256, 1)
#
# VALIDATION SET:
# X_val shape: (489, 256, 256, 3)
# y_val shape: (489, 256, 256, 1)
#
# TEST SET:
# X_test shape: (489, 256, 256, 3)
# y_test shape: (489, 256, 256, 1)

# %%
# Sizes of each dataset
sizes = [len(X_train), len(X_val), len(X_test)]
labels = ['Train Set', 'Validation Set', 'Test Set']
colors = ['#7FC8A9','#FFD166','#EF476F']
explode = (0.1, 0, 0)  # explode the 1st slice (Train Set)

# Plotting the pie chart
plt.figure(figsize=(8, 8))
plt.pie(sizes, explode=explode, labels=labels, colors=colors, autopct='%1.1f%%',
        shadow=True, startangle=140)
plt.title('Dataset Distribution')
plt.show()

# %% [markdown]
# # U-Net

# %%
# Convolutional Block (Double Convolution)
def double_conv_block(x, N_FILTERS):
    x = Conv2D(N_FILTERS, 3, padding="same", activation="relu", kernel_initializer="he_normal")(x)
    x = Conv2D(N_FILTERS, 3, padding="same", activation="relu", kernel_initializer="he_normal")(x)
    return x

# Downsample Block (Conv + MaxPooling)
def downsample_block(x, N_FILTERS):
    f = double_conv_block(x, N_FILTERS)
    p = MaxPooling2D(2)(f)
    return f, p

# Upsample Block (Transposed Conv + Concatenate + Double Convolution)
def upsample_block(x, conv_features, N_FILTERS):
    x = Conv2DTranspose(N_FILTERS, 3, 2, padding="same")(x)
    x = concatenate([x, conv_features])
    x = double_conv_block(x, N_FILTERS)
    return x

# Feature Pyramid Network (FPN) block
def fpn_block(x, prev_feature_map=None, N_FILTERS=256):
    # 1x1 conv to reduce channels
    x = Conv2D(N_FILTERS, 1, padding="same", activation="relu")(x)
    
    # If previous feature map exists, upsample and combine with current feature map
    if prev_feature_map is not None:
        # Upsample the previous feature map to match the current feature map's spatial dimensions
        prev_feature_map_upsampled = UpSampling2D(size=(2, 2))(prev_feature_map)
        
        # Apply a 1x1 conv to adjust the number of channels in the previous feature map (if necessary)
        prev_feature_map_upsampled = Conv2D(N_FILTERS, 1, padding="same", activation="relu")(prev_feature_map_upsampled)
        
        # Now add the two feature maps
        x = Add()([x, prev_feature_map_upsampled])
    
    # Apply a 3x3 conv for smoothing and refine features
    x = Conv2D(N_FILTERS, 3, padding="same", activation="relu")(x)
    return x

# %%
# U-Net Architecture with FPN only in the encoder path
inputs = Input(IMG_SHAPE)

# Encoder Path with downsampling
f1, p1 = downsample_block(inputs, 64)
f2, p2 = downsample_block(p1, 128)
f3, p3 = downsample_block(p2, 256)
f4, p4 = downsample_block(p3, 512)

# FPN applied only in the encoder (multiscale feature fusion)
f4 = fpn_block(f4, N_FILTERS=512)  # Apply FPN at the deepest encoder layer
f3 = fpn_block(f3, f4, N_FILTERS=256)  # Apply FPN with connection from f4
f2 = fpn_block(f2, f3, N_FILTERS=128)  # Apply FPN with connection from f3

# Bottleneck (unchanged)
bottleneck = double_conv_block(p4, 1024)

# Decoder Path (using original skip connections from encoder)
u6 = upsample_block(bottleneck, f4, 512)
u7 = upsample_block(u6, f3, 256)
u8 = upsample_block(u7, f2, 128)
u9 = upsample_block(u8, f1, 64)

# Output Layer (Segmentation)
outputs = Conv2D(N_CLASSES, 1, padding="same", activation="sigmoid")(u9)

# Create Model
unet_fpn_model = Model(inputs, outputs, name="U-Net-with-FPN-Encoder")

# Print model summary
unet_fpn_model.summary()

# Plot the Model (to visualize the updated FPN structure)
plot_model(unet_fpn_model, show_shapes=True, show_layer_names=True, dpi=120)
# Out:
# Model: "U-Net-with-FPN-Encoder"
# ┏━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)        ┃ Output Shape      ┃    Param # ┃ Connected to      ┃
# ┡━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━┩
# │ input_layer         │ (None, 256, 256,  │          0 │ -                 │
# │ (InputLayer)        │ 3)                │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d (Conv2D)     │ (None, 256, 256,  │      1,792 │ input_layer[0][0] │
# │                     │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_1 (Conv2D)   │ (None, 256, 256,  │     36,928 │ conv2d[0][0]      │
# │                     │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ max_pooling2d       │ (None, 128, 128,  │          0 │ conv2d_1[0][0]    │
# │ (MaxPooling2D)      │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_2 (Conv2D)   │ (None, 128, 128,  │     73,856 │ max_pooling2d[0]… │
# │                     │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_3 (Conv2D)   │ (None, 128, 128,  │    147,584 │ conv2d_2[0][0]    │
# │                     │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ max_pooling2d_1     │ (None, 64, 64,    │          0 │ conv2d_3[0][0]    │
# │ (MaxPooling2D)      │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_4 (Conv2D)   │ (None, 64, 64,    │    295,168 │ max_pooling2d_1[… │
# │                     │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_5 (Conv2D)   │ (None, 64, 64,    │    590,080 │ conv2d_4[0][0]    │
# │                     │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ max_pooling2d_2     │ (None, 32, 32,    │          0 │ conv2d_5[0][0]    │
# │ (MaxPooling2D)      │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_6 (Conv2D)   │ (None, 32, 32,    │  1,180,160 │ max_pooling2d_2[… │
# │                     │ 512)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_7 (Conv2D)   │ (None, 32, 32,    │  2,359,808 │ conv2d_6[0][0]    │
# │                     │ 512)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ max_pooling2d_3     │ (None, 16, 16,    │          0 │ conv2d_7[0][0]    │
# │ (MaxPooling2D)      │ 512)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_16 (Conv2D)  │ (None, 16, 16,    │  4,719,616 │ max_pooling2d_3[… │
# │                     │ 1024)             │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_17 (Conv2D)  │ (None, 16, 16,    │  9,438,208 │ conv2d_16[0][0]   │
# │                     │ 1024)             │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_8 (Conv2D)   │ (None, 32, 32,    │    262,656 │ conv2d_7[0][0]    │
# │                     │ 512)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_transpose    │ (None, 32, 32,    │  4,719,104 │ conv2d_17[0][0]   │
# │ (Conv2DTranspose)   │ 512)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_9 (Conv2D)   │ (None, 32, 32,    │  2,359,808 │ conv2d_8[0][0]    │
# │                     │ 512)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ concatenate         │ (None, 32, 32,    │          0 │ conv2d_transpose… │
# │ (Concatenate)       │ 1024)             │            │ conv2d_9[0][0]    │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ up_sampling2d       │ (None, 64, 64,    │          0 │ conv2d_9[0][0]    │
# │ (UpSampling2D)      │ 512)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_18 (Conv2D)  │ (None, 32, 32,    │  4,719,104 │ concatenate[0][0] │
# │                     │ 512)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_10 (Conv2D)  │ (None, 64, 64,    │     65,792 │ conv2d_5[0][0]    │
# │                     │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_11 (Conv2D)  │ (None, 64, 64,    │    131,328 │ up_sampling2d[0]… │
# │                     │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_19 (Conv2D)  │ (None, 32, 32,    │  2,359,808 │ conv2d_18[0][0]   │
# │                     │ 512)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ add (Add)           │ (None, 64, 64,    │          0 │ conv2d_10[0][0],  │
# │                     │ 256)              │            │ conv2d_11[0][0]   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_transpose_1  │ (None, 64, 64,    │  1,179,904 │ conv2d_19[0][0]   │
# │ (Conv2DTranspose)   │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_12 (Conv2D)  │ (None, 64, 64,    │    590,080 │ add[0][0]         │
# │                     │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ concatenate_1       │ (None, 64, 64,    │          0 │ conv2d_transpose… │
# │ (Concatenate)       │ 512)              │            │ conv2d_12[0][0]   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ up_sampling2d_1     │ (None, 128, 128,  │          0 │ conv2d_12[0][0]   │
# │ (UpSampling2D)      │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_20 (Conv2D)  │ (None, 64, 64,    │  1,179,904 │ concatenate_1[0]… │
# │                     │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_13 (Conv2D)  │ (None, 128, 128,  │     16,512 │ conv2d_3[0][0]    │
# │                     │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_14 (Conv2D)  │ (None, 128, 128,  │     32,896 │ up_sampling2d_1[… │
# │                     │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_21 (Conv2D)  │ (None, 64, 64,    │    590,080 │ conv2d_20[0][0]   │
# │                     │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ add_1 (Add)         │ (None, 128, 128,  │          0 │ conv2d_13[0][0],  │
# │                     │ 128)              │            │ conv2d_14[0][0]   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_transpose_2  │ (None, 128, 128,  │    295,040 │ conv2d_21[0][0]   │
# │ (Conv2DTranspose)   │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_15 (Conv2D)  │ (None, 128, 128,  │    147,584 │ add_1[0][0]       │
# │                     │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ concatenate_2       │ (None, 128, 128,  │          0 │ conv2d_transpose… │
# │ (Concatenate)       │ 256)              │            │ conv2d_15[0][0]   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_22 (Conv2D)  │ (None, 128, 128,  │    295,040 │ concatenate_2[0]… │
# │                     │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_23 (Conv2D)  │ (None, 128, 128,  │    147,584 │ conv2d_22[0][0]   │
# │                     │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_transpose_3  │ (None, 256, 256,  │     73,792 │ conv2d_23[0][0]   │
# │ (Conv2DTranspose)   │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ concatenate_3       │ (None, 256, 256,  │          0 │ conv2d_transpose… │
# │ (Concatenate)       │ 128)              │            │ conv2d_1[0][0]    │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_24 (Conv2D)  │ (None, 256, 256,  │     73,792 │ concatenate_3[0]… │
# │                     │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_25 (Conv2D)  │ (None, 256, 256,  │     36,928 │ conv2d_24[0][0]   │
# │                     │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_26 (Conv2D)  │ (None, 256, 256,  │         65 │ conv2d_25[0][0]   │
# │                     │ 1)                │            │                   │
# └─────────────────────┴───────────────────┴────────────┴───────────────────┘
#  Total params: 38,120,001 (145.42 MB)
#  Trainable params: 38,120,001 (145.42 MB)
#  Non-trainable params: 0 (0.00 B)

# %%
# Cell 3 (Keep this - metrics are needed for model compilation)
# Dice Coefficient
def dice_coefficient(y_true, y_pred, smooth=1.0):
    y_true_f = tf.keras.backend.flatten(y_true)
    y_pred_f = tf.keras.backend.flatten(y_pred)
    intersection = tf.keras.backend.sum(y_true_f * y_pred_f)
    return (2. * intersection + smooth) / (tf.keras.backend.sum(y_true_f) + tf.keras.backend.sum(y_pred_f) + smooth)

# Dice Loss
def dice_loss(y_true, y_pred):
    return 1 - dice_coefficient(y_true, y_pred)

# IoU Metric
def iou_metric(y_true, y_pred, smooth=1.0):
    intersection = tf.keras.backend.sum(tf.keras.backend.abs(y_true * y_pred), axis=[1, 2, 3])
    union = tf.keras.backend.sum(y_true, axis=[1, 2, 3]) + tf.keras.backend.sum(y_pred, axis=[1, 2, 3]) - intersection
    iou = tf.keras.backend.mean((intersection + smooth) / (union + smooth), axis=0)
    return iou

# %%
# Cell 4 (Updated compilation with correct metric names)
optimizer = Adam(learning_rate=LEARNING_RATE)
metrics = [
    'accuracy',
    'Precision',
    'Recall',
    iou_metric,
    dice_coefficient
]

unet_fpn_model.compile(
    optimizer=optimizer,
    loss='binary_crossentropy',
    metrics=metrics
)

callbacks = [
    ReduceLROnPlateau(monitor='val_loss', factor=0.2, patience=3, verbose=1),
    EarlyStopping(monitor='val_loss', patience=8, restore_best_weights=True),
    ModelCheckpoint(f'{EXPERIMENT_NAME}_best_model.keras', 
                   monitor='val_loss', 
                   save_best_only=True)
]

history = unet_fpn_model.fit(
    train_ds,
    validation_data=val_ds,
    epochs=EPOCHS,
    callbacks=callbacks,
    verbose=1
)
# Out:
# Epoch 1/35
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# I0000 00:00:1733454597.384508      96 service.cc:145] XLA service 0x7fe704002170 initialized for platform CUDA (this does not guarantee that XLA will be used). Devices:
# I0000 00:00:1733454597.384578      96 service.cc:153]   StreamExecutor device (0): Tesla P100-PCIE-16GB, Compute Capability 6.0
# I0000 00:00:1733454667.940035      96 device_compiler.h:188] Compiled cluster using XLA!  This line is logged at most once for the lifetime of the process.
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 177s 1s/step - Precision: 0.5541 - Recall: 0.2621 - accuracy: 0.9197 - dice_coefficient: 0.3193 - iou_metric: 0.1688 - loss: 0.9220 - val_Precision: 0.7877 - val_Recall: 0.9222 - val_accuracy: 0.9721 - val_dice_coefficient: 0.7522 - val_iou_metric: 0.5036 - val_loss: 0.0763 - learning_rate: 0.0010
# Epoch 2/35
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 66s 919ms/step - Precision: 0.8306 - Recall: 0.8408 - accuracy: 0.9739 - dice_coefficient: 0.7547 - iou_metric: 0.4933 - loss: 0.0667 - val_Precision: 0.8854 - val_Recall: 0.9146 - val_accuracy: 0.9826 - val_dice_coefficient: 0.8403 - val_iou_metric: 0.5955 - val_loss: 0.0457 - learning_rate: 0.0010
# Epoch 3/35
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 66s 918ms/step - Precision: 0.9072 - Recall: 0.9028 - accuracy: 0.9854 - dice_coefficient: 0.8480 - iou_metric: 0.5834 - loss: 0.0385 - val_Precision: 0.9112 - val_Recall: 0.9155 - val_accuracy: 0.9851 - val_dice_coefficient: 0.8697 - val_iou_metric: 0.6417 - val_loss: 0.0386 - learning_rate: 0.0010
# Epoch 4/35
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 64s 890ms/step - Precision: 0.8686 - Recall: 0.8564 - accuracy: 0.9781 - dice_coefficient: 0.8063 - iou_metric: 0.5788 - loss: 0.0848 - val_Precision: 0.8094 - val_Recall: 0.8486 - val_accuracy: 0.9700 - val_dice_coefficient: 0.7458 - val_iou_metric: 0.4922 - val_loss: 0.0901 - learning_rate: 0.0010
# Epoch 5/35
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 64s 890ms/step - Precision: 0.8588 - Recall: 0.8342 - accuracy: 0.9753 - dice_coefficient: 0.7641 - iou_metric: 0.4947 - loss: 0.0680 - val_Precision: 0.8645 - val_Recall: 0.9360 - val_accuracy: 0.9820 - val_dice_coefficient: 0.8620 - val_iou_metric: 0.6132 - val_loss: 0.0472 - learning_rate: 0.0010
# Epoch 6/35
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 66s 918ms/step - Precision: 0.9043 - Recall: 0.9129 - accuracy: 0.9851 - dice_coefficient: 0.8628 - iou_metric: 0.6102 - loss: 0.0386 - val_Precision: 0.8952 - val_Recall: 0.9366 - val_accuracy: 0.9852 - val_dice_coefficient: 0.8786 - val_iou_metric: 0.6514 - val_loss: 0.0381 - learning_rate: 0.0010
# Epoch 7/35
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 66s 919ms/step - Precision: 0.9150 - Recall: 0.9178 - accuracy: 0.9867 - dice_coefficient: 0.8756 - iou_metric: 0.6218 - loss: 0.0341 - val_Precision: 0.9187 - val_Recall: 0.9227 - val_accuracy: 0.9864 - val_dice_coefficient: 0.8864 - val_iou_metric: 0.6658 - val_loss: 0.0348 - learning_rate: 0.0010
# Epoch 8/35
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 66s 918ms/step - Precision: 0.9204 - Recall: 0.9207 - accuracy: 0.9874 - dice_coefficient: 0.8827 - iou_metric: 0.6435 - loss: 0.0323 - val_Precision: 0.9411 - val_Recall: 0.9001 - val_accuracy: 0.9866 - val_dice_coefficient: 0.8818 - val_iou_metric: 0.6579 - val_loss: 0.0340 - learning_rate: 0.0010
# Epoch 9/35
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 66s 918ms/step - Precision: 0.9243 - Recall: 0.9232 - accuracy: 0.9881 - dice_coefficient: 0.8865 - iou_metric: 0.6454 - loss: 0.0301 - val_Precision: 0.9212 - val_Recall: 0.9316 - val_accuracy: 0.9873 - val_dice_coefficient: 0.8919 - val_iou_metric: 0.6768 - val_loss: 0.0318 - learning_rate: 0.0010
# Epoch 10/35
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 66s 918ms/step - Precision: 0.9235 - Recall: 0.9255 - accuracy: 0.9878 - dice_coefficient: 0.8890 - iou_metric: 0.6494 - loss: 0.0305 - val_Precision: 0.9255 - val_Recall: 0.9319 - val_accuracy: 0.9878 - val_dice_coefficient: 0.8917 - val_iou_metric: 0.6783 - val_loss: 0.0306 - learning_rate: 0.0010
# Epoch 11/35
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 66s 919ms/step - Precision: 0.9277 - Recall: 0.9298 - accuracy: 0.9888 - dice_coefficient: 0.8944 - iou_metric: 0.6509 - loss: 0.0279 - val_Precision: 0.9320 - val_Recall: 0.9328 - val_accuracy: 0.9884 - val_dice_coefficient: 0.9038 - val_iou_metric: 0.6931 - val_loss: 0.0291 - learning_rate: 0.0010
# Epoch 12/35
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 66s 919ms/step - Precision: 0.9297 - Recall: 0.9307 - accuracy: 0.9889 - dice_coefficient: 0.8974 - iou_metric: 0.6764 - loss: 0.0279 - val_Precision: 0.9385 - val_Recall: 0.9274 - val_accuracy: 0.9886 - val_dice_coefficient: 0.8988 - val_iou_metric: 0.6927 - val_loss: 0.0287 - learning_rate: 0.0010
# Epoch 13/35
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 66s 920ms/step - Precision: 0.9336 - Recall: 0.9339 - accuracy: 0.9896 - dice_coefficient: 0.9012 - iou_metric: 0.6754 - loss: 0.0261 - val_Precision: 0.9261 - val_Recall: 0.9441 - val_accuracy: 0.9888 - val_dice_coefficient: 0.9071 - val_iou_metric: 0.7016 - val_loss: 0.0281 - learning_rate: 0.0010
# Epoch 14/35
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 66s 919ms/step - Precision: 0.9337 - Recall: 0.9372 - accuracy: 0.9896 - dice_coefficient: 0.9048 - iou_metric: 0.6815 - loss: 0.0258 - val_Precision: 0.9304 - val_Recall: 0.9433 - val_accuracy: 0.9891 - val_dice_coefficient: 0.9080 - val_iou_metric: 0.7058 - val_loss: 0.0271 - learning_rate: 0.0010
# Epoch 15/35
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 64s 891ms/step - Precision: 0.9319 - Recall: 0.9370 - accuracy: 0.9896 - dice_coefficient: 0.9036 - iou_metric: 0.6802 - loss: 0.0258 - val_Precision: 0.9236 - val_Recall: 0.9473 - val_accuracy: 0.9888 - val_dice_coefficient: 0.9093 - val_iou_metric: 0.7040 - val_loss: 0.0279 - learning_rate: 0.0010
# Epoch 16/35
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 64s 891ms/step - Precision: 0.9342 - Recall: 0.9376 - accuracy: 0.9901 - dice_coefficient: 0.9058 - iou_metric: 0.6741 - loss: 0.0246 - val_Precision: 0.9235 - val_Recall: 0.9507 - val_accuracy: 0.9890 - val_dice_coefficient: 0.9050 - val_iou_metric: 0.7013 - val_loss: 0.0271 - learning_rate: 0.0010
# Epoch 17/35
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 66s 918ms/step - Precision: 0.9338 - Recall: 0.9406 - accuracy: 0.9898 - dice_coefficient: 0.9074 - iou_metric: 0.6859 - loss: 0.0252 - val_Precision: 0.9390 - val_Recall: 0.9368 - val_accuracy: 0.9894 - val_dice_coefficient: 0.9051 - val_iou_metric: 0.7019 - val_loss: 0.0263 - learning_rate: 0.0010
# Epoch 18/35
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 64s 892ms/step - Precision: 0.9367 - Recall: 0.9415 - accuracy: 0.9902 - dice_coefficient: 0.9099 - iou_metric: 0.6929 - loss: 0.0241 - val_Precision: 0.9041 - val_Recall: 0.9669 - val_accuracy: 0.9884 - val_dice_coefficient: 0.9053 - val_iou_metric: 0.7018 - val_loss: 0.0287 - learning_rate: 0.0010
# Epoch 19/35
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 64s 892ms/step - Precision: 0.9337 - Recall: 0.9417 - accuracy: 0.9903 - dice_coefficient: 0.9085 - iou_metric: 0.6843 - loss: 0.0237 - val_Precision: 0.9161 - val_Recall: 0.9600 - val_accuracy: 0.9891 - val_dice_coefficient: 0.9138 - val_iou_metric: 0.7182 - val_loss: 0.0272 - learning_rate: 0.0010
# Epoch 20/35
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 66s 919ms/step - Precision: 0.9354 - Recall: 0.9419 - accuracy: 0.9905 - dice_coefficient: 0.9107 - iou_metric: 0.6837 - loss: 0.0232 - val_Precision: 0.9264 - val_Recall: 0.9532 - val_accuracy: 0.9895 - val_dice_coefficient: 0.9103 - val_iou_metric: 0.7132 - val_loss: 0.0257 - learning_rate: 0.0010
# Epoch 21/35
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 66s 920ms/step - Precision: 0.9373 - Recall: 0.9438 - accuracy: 0.9903 - dice_coefficient: 0.9127 - iou_metric: 0.6998 - loss: 0.0237 - val_Precision: 0.9413 - val_Recall: 0.9392 - val_accuracy: 0.9898 - val_dice_coefficient: 0.9148 - val_iou_metric: 0.7216 - val_loss: 0.0251 - learning_rate: 0.0010
# Epoch 22/35
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 66s 919ms/step - Precision: 0.9379 - Recall: 0.9429 - accuracy: 0.9905 - dice_coefficient: 0.9130 - iou_metric: 0.6991 - loss: 0.0232 - val_Precision: 0.9438 - val_Recall: 0.9368 - val_accuracy: 0.9898 - val_dice_coefficient: 0.9154 - val_iou_metric: 0.7202 - val_loss: 0.0250 - learning_rate: 0.0010
# Epoch 23/35
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 64s 891ms/step - Precision: 0.9380 - Recall: 0.9427 - accuracy: 0.9906 - dice_coefficient: 0.9126 - iou_metric: 0.6941 - loss: 0.0229 - val_Precision: 0.9059 - val_Recall: 0.9682 - val_accuracy: 0.9887 - val_dice_coefficient: 0.9161 - val_iou_metric: 0.7247 - val_loss: 0.0283 - learning_rate: 0.0010
# Epoch 24/35
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 66s 916ms/step - Precision: 0.9346 - Recall: 0.9440 - accuracy: 0.9905 - dice_coefficient: 0.9117 - iou_metric: 0.6845 - loss: 0.0232 - val_Precision: 0.9284 - val_Recall: 0.9548 - val_accuracy: 0.9898 - val_dice_coefficient: 0.9155 - val_iou_metric: 0.7254 - val_loss: 0.0247 - learning_rate: 0.0010
# Epoch 25/35
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 64s 891ms/step - Precision: 0.9387 - Recall: 0.9448 - accuracy: 0.9909 - dice_coefficient: 0.9149 - iou_metric: 0.6991 - loss: 0.0221 - val_Precision: 0.9235 - val_Recall: 0.9603 - val_accuracy: 0.9898 - val_dice_coefficient: 0.9169 - val_iou_metric: 0.7266 - val_loss: 0.0248 - learning_rate: 0.0010
# Epoch 26/35
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 66s 919ms/step - Precision: 0.9375 - Recall: 0.9458 - accuracy: 0.9907 - dice_coefficient: 0.9152 - iou_metric: 0.6973 - loss: 0.0225 - val_Precision: 0.9362 - val_Recall: 0.9496 - val_accuracy: 0.9902 - val_dice_coefficient: 0.9175 - val_iou_metric: 0.7277 - val_loss: 0.0239 - learning_rate: 0.0010
# Epoch 27/35
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 64s 891ms/step - Precision: 0.9401 - Recall: 0.9453 - accuracy: 0.9909 - dice_coefficient: 0.9162 - iou_metric: 0.7089 - loss: 0.0221 - val_Precision: 0.9414 - val_Recall: 0.9431 - val_accuracy: 0.9901 - val_dice_coefficient: 0.9190 - val_iou_metric: 0.7265 - val_loss: 0.0241 - learning_rate: 0.0010
# Epoch 28/35
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 64s 891ms/step - Precision: 0.9421 - Recall: 0.9469 - accuracy: 0.9910 - dice_coefficient: 0.9190 - iou_metric: 0.7156 - loss: 0.0219 - val_Precision: 0.9504 - val_Recall: 0.9326 - val_accuracy: 0.9901 - val_dice_coefficient: 0.9141 - val_iou_metric: 0.7200 - val_loss: 0.0242 - learning_rate: 0.0010
# Epoch 29/35
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 0s 832ms/step - Precision: 0.9429 - Recall: 0.9464 - accuracy: 0.9911 - dice_coefficient: 0.9191 - iou_metric: 0.7081 - loss: 0.0215
# Epoch 29: ReduceLROnPlateau reducing learning rate to 0.00020000000949949026.
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 64s 891ms/step - Precision: 0.9429 - Recall: 0.9464 - accuracy: 0.9911 - dice_coefficient: 0.9191 - iou_metric: 0.7081 - loss: 0.0215 - val_Precision: 0.9328 - val_Recall: 0.9534 - val_accuracy: 0.9901 - val_dice_coefficient: 0.9240 - val_iou_metric: 0.7381 - val_loss: 0.0245 - learning_rate: 0.0010
# Epoch 30/35
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 66s 920ms/step - Precision: 0.9428 - Recall: 0.9482 - accuracy: 0.9914 - dice_coefficient: 0.9205 - iou_metric: 0.7097 - loss: 0.0208 - val_Precision: 0.9419 - val_Recall: 0.9468 - val_accuracy: 0.9905 - val_dice_coefficient: 0.9213 - val_iou_metric: 0.7354 - val_loss: 0.0232 - learning_rate: 2.0000e-04
# Epoch 31/35
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 66s 920ms/step - Precision: 0.9443 - Recall: 0.9486 - accuracy: 0.9917 - dice_coefficient: 0.9224 - iou_metric: 0.7124 - loss: 0.0201 - val_Precision: 0.9423 - val_Recall: 0.9465 - val_accuracy: 0.9905 - val_dice_coefficient: 0.9213 - val_iou_metric: 0.7346 - val_loss: 0.0231 - learning_rate: 2.0000e-04
# Epoch 32/35
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 64s 892ms/step - Precision: 0.9446 - Recall: 0.9480 - accuracy: 0.9915 - dice_coefficient: 0.9216 - iou_metric: 0.7169 - loss: 0.0204 - val_Precision: 0.9445 - val_Recall: 0.9438 - val_accuracy: 0.9905 - val_dice_coefficient: 0.9218 - val_iou_metric: 0.7353 - val_loss: 0.0232 - learning_rate: 2.0000e-04
# Epoch 33/35
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 0s 832ms/step - Precision: 0.9459 - Recall: 0.9493 - accuracy: 0.9919 - dice_coefficient: 0.9237 - iou_metric: 0.7202 - loss: 0.0196
# Epoch 33: ReduceLROnPlateau reducing learning rate to 4.0000001899898055e-05.
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 64s 891ms/step - Precision: 0.9459 - Recall: 0.9493 - accuracy: 0.9919 - dice_coefficient: 0.9236 - iou_metric: 0.7201 - loss: 0.0196 - val_Precision: 0.9445 - val_Recall: 0.9437 - val_accuracy: 0.9904 - val_dice_coefficient: 0.9201 - val_iou_metric: 0.7341 - val_loss: 0.0232 - learning_rate: 2.0000e-04
# Epoch 34/35
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 64s 891ms/step - Precision: 0.9458 - Recall: 0.9493 - accuracy: 0.9917 - dice_coefficient: 0.9232 - iou_metric: 0.7207 - loss: 0.0200 - val_Precision: 0.9419 - val_Recall: 0.9468 - val_accuracy: 0.9905 - val_dice_coefficient: 0.9222 - val_iou_metric: 0.7369 - val_loss: 0.0231 - learning_rate: 4.0000e-05
# Epoch 35/35
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 66s 920ms/step - Precision: 0.9455 - Recall: 0.9497 - accuracy: 0.9916 - dice_coefficient: 0.9233 - iou_metric: 0.7231 - loss: 0.0202 - val_Precision: 0.9419 - val_Recall: 0.9468 - val_accuracy: 0.9905 - val_dice_coefficient: 0.9216 - val_iou_metric: 0.7359 - val_loss: 0.0231 - learning_rate: 4.0000e-05

# %% [markdown]
# # Results

# %%
# Get the best epochs for each metric
best_val_loss_epoch = np.argmin(history.history['val_loss']) + 1
best_val_dice_epoch = np.argmax(history.history['val_dice_coefficient']) + 1
best_val_iou_epoch = np.argmax(history.history['val_iou_metric']) + 1
best_val_acc_epoch = np.argmax(history.history['val_accuracy']) + 1

# Calculate the best metric values
min_val_loss = np.min(history.history['val_loss'])
max_val_dice = np.max(history.history['val_dice_coefficient'])
max_val_iou = np.max(history.history['val_iou_metric'])
max_val_acc = np.max(history.history['val_accuracy'])

# Plot Accuracy
plt.figure(figsize=(8, 6))
plt.plot(history.history['accuracy'], 'b-', label='Training Accuracy', linewidth=2)
plt.plot(history.history['val_accuracy'], 'r-', label='Validation Accuracy', linewidth=2)
plt.axvline(x=best_val_acc_epoch, color='g', linestyle='--', label=f'Best Epoch ({best_val_acc_epoch})')
plt.title('U-Net + FPN Model | Training and Validation Accuracy', fontsize=14, pad=15)
plt.xlabel('Epoch', fontsize=12)
plt.ylabel('Accuracy', fontsize=12)
plt.legend(fontsize=10)
plt.grid(True, linestyle='--', alpha=0.7)
plt.tight_layout()
plt.show()

# Plot Loss
plt.figure(figsize=(8, 6))
plt.plot(history.history['loss'], 'b-', label='Training Loss', linewidth=2)
plt.plot(history.history['val_loss'], 'r-', label='Validation Loss', linewidth=2)
plt.axvline(x=best_val_loss_epoch, color='g', linestyle='--', label=f'Best Epoch ({best_val_loss_epoch})')
plt.title('U-Net + FPN Model | Training and Validation Loss', fontsize=14, pad=15)
plt.xlabel('Epoch', fontsize=12)
plt.ylabel('Loss', fontsize=12)
plt.legend(fontsize=10)
plt.grid(True, linestyle='--', alpha=0.7)
plt.tight_layout()
plt.show()

# Plot Dice Coefficient
plt.figure(figsize=(8, 6))
plt.plot(history.history['dice_coefficient'], 'b-', label='Training Dice', linewidth=2)
plt.plot(history.history['val_dice_coefficient'], 'r-', label='Validation Dice', linewidth=2)
plt.axvline(x=best_val_dice_epoch, color='g', linestyle='--', label=f'Best Epoch ({best_val_dice_epoch})')
plt.title('U-Net + FPN Model | Training and Validation Dice Coefficient', fontsize=14, pad=15)
plt.xlabel('Epoch', fontsize=12)
plt.ylabel('Dice Coefficient', fontsize=12)
plt.legend(fontsize=10)
plt.grid(True, linestyle='--', alpha=0.7)
plt.tight_layout()
plt.show()

# Plot IoU
plt.figure(figsize=(8, 6))
plt.plot(history.history['iou_metric'], 'b-', label='Training IoU', linewidth=2)
plt.plot(history.history['val_iou_metric'], 'r-', label='Validation IoU', linewidth=2)
plt.axvline(x=best_val_iou_epoch, color='g', linestyle='--', label=f'Best Epoch ({best_val_iou_epoch})')
plt.title('U-Net + FPN Model | Training and Validation IoU Metric', fontsize=14, pad=15)
plt.xlabel('Epoch', fontsize=12)
plt.ylabel('IoU', fontsize=12)
plt.legend(fontsize=10)
plt.grid(True, linestyle='--', alpha=0.7)
plt.tight_layout()
plt.show()

# Print summary of best epochs and values
print("\nBest Epochs Summary:")
print("-" * 50)
print(f"Loss - Epoch: {best_val_loss_epoch:3d}, Value: {min_val_loss:.4f}")
print(f"Dice - Epoch: {best_val_dice_epoch:3d}, Value: {max_val_dice:.4f}")
print(f"IoU - Epoch: {best_val_iou_epoch:3d}, Value: {max_val_iou:.4f}")
print(f"Accuracy - Epoch: {best_val_acc_epoch:3d}, Value: {max_val_acc:.4f}")
# Out:
# Best Epochs Summary:
# --------------------------------------------------
# Loss - Epoch:  35, Value: 0.0231
# Dice - Epoch:  29, Value: 0.9240
# IoU - Epoch:  29, Value: 0.7381
# Accuracy - Epoch:  31, Value: 0.9905

# %%
def evaluate_model(model, X, y, batch_size=10):
    return model.evaluate(X, y, batch_size=batch_size, verbose=0)

# Store results for comparison
results_dict = {}
# Get evaluation results without printing
results_dict['train'] = evaluate_model(unet_fpn_model, X_train, y_train, batch_size=10)
results_dict['val'] = evaluate_model(unet_fpn_model, X_val, y_val, batch_size=10)
results_dict['test'] = evaluate_model(unet_fpn_model, X_test, y_test, batch_size=10)

# Create comparison table
metrics_names = ['Loss', 'Accuracy', 'Precision', 'Recall', 'IoU', 'Dice']
print("\nMetrics Comparison Across Datasets:")
print("-" * 65)
print(f"{'Metric':15} {'Training':15} {'Validation':15} {'Test':15}")
print("-" * 65)
for i, metric in enumerate(metrics_names):
    train_val = results_dict['train'][i]
    val_val = results_dict['val'][i]
    test_val = results_dict['test'][i]
    print(f"{metric:15} {train_val:15.4f} {val_val:15.4f} {test_val:15.4f}")
print("-" * 65)

# Visualize metrics comparison
plt.figure(figsize=(12, 6))
x = np.arange(len(metrics_names))
width = 0.25

plt.bar(x - width, results_dict['train'], width, label='Training', color='#7FC8A9')
plt.bar(x, results_dict['val'], width, label='Validation', color='#FFD166')
plt.bar(x + width, results_dict['test'], width, label='Test', color='#EF476F')

plt.xlabel('Metrics')
plt.ylabel('Values')
plt.title('U-Net + FPN Model Performance Comparison Across Datasets')
plt.xticks(x, metrics_names, rotation=45)
plt.legend()
plt.tight_layout()
plt.show()
# Out:
# Metrics Comparison Across Datasets:
# -----------------------------------------------------------------
# Metric          Training        Validation      Test
# -----------------------------------------------------------------
# Loss                     0.0200          0.0231          0.0216
# Accuracy                 0.9917          0.9905          0.9910
# Precision                0.9454          0.9419          0.9376
# Recall                   0.9503          0.9468          0.9425
# IoU                      0.7197          0.7410          0.7103
# Dice                     0.9220          0.9201          0.9138
# -----------------------------------------------------------------

# %%
# Calculate differences between datasets
def calculate_differences():
    datasets = ['Train', 'Val', 'Test']
    diff_matrix = np.zeros((len(metrics_names), len(datasets), len(datasets)))
    
    for i, metric in enumerate(metrics_names):
        for j, d1 in enumerate(datasets):
            for k, d2 in enumerate(datasets):
                if j != k:  # Skip comparing dataset with itself
                    d1_lower = d1.lower()
                    d2_lower = d2.lower()
                    diff = results_dict[d1_lower][i] - results_dict[d2_lower][i]
                    diff_matrix[i, j, k] = diff
    
    return diff_matrix

# Create heatmap for each metric
diff_matrix = calculate_differences()
datasets = ['Train', 'Val', 'Test']

# Create a figure with subplots for each metric
fig, axes = plt.subplots(2, 3, figsize=(20, 15))
axes = axes.ravel()

# Create heatmaps
for i, metric in enumerate(metrics_names):
    ax = axes[i]
    
    # Create heatmap data for this metric
    heatmap_data = diff_matrix[i]
    
    # Create mask for diagonal (self-comparison)
    mask = np.eye(len(datasets), dtype=bool)
    
    # Plot heatmap
    sns.heatmap(heatmap_data, 
                annot=True, 
                fmt='.4f', 
                cmap='RdBu_r',
                center=0,
                mask=mask,
                xticklabels=datasets,
                yticklabels=datasets,
                ax=ax,
                cbar_kws={'label': 'Difference'})
    
    ax.set_title(f'{metric} Differences')
    ax.set_xlabel('Dataset')
    ax.set_ylabel('Dataset')

plt.tight_layout()
plt.show()

# Print detailed analysis
print("\nDetailed Metrics Differences Analysis:")
print("-" * 70)
for i, metric in enumerate(metrics_names):
    print(f"\n{metric} Differences:")
    print("-" * 40)
    for j, d1 in enumerate(datasets):
        for k, d2 in enumerate(datasets):
            if j < k:  # Only print each comparison once
                diff = diff_matrix[i, j, k]
                print(f"{d1} vs {d2}: {diff:+.4f}")
                if abs(diff) > 0.1:  # Flag significant differences
                    print(f"   ⚠️ Large difference detected!")
                    if diff > 0:
                        print(f"   • {d1} performs better than {d2}")
                    else:
                        print(f"   • {d2} performs better than {d1}")
# Out:
# Detailed Metrics Differences Analysis:
# ----------------------------------------------------------------------
#
# Loss Differences:
# ----------------------------------------
# Train vs Val: -0.0031
# Train vs Test: -0.0016
# Val vs Test: +0.0015
#
# Accuracy Differences:
# ----------------------------------------
# Train vs Val: +0.0012
# Train vs Test: +0.0007
# Val vs Test: -0.0005
#
# Precision Differences:
# ----------------------------------------
# Train vs Val: +0.0036
# Train vs Test: +0.0078
# Val vs Test: +0.0042
#
# Recall Differences:
# ----------------------------------------
# Train vs Val: +0.0034
# Train vs Test: +0.0077
# Val vs Test: +0.0043
#
# IoU Differences:
# ----------------------------------------
# Train vs Val: -0.0213
# Train vs Test: +0.0094
# Val vs Test: +0.0307
#
# Dice Differences:
# ----------------------------------------
# Train vs Val: +0.0019
# Train vs Test: +0.0083
# Val vs Test: +0.0064

# %%
def visualize_prediction(model, X_test, y_test, idx=None):
    if idx is None:
        idx = np.random.randint(0, len(X_test))
    
    test_img = X_test[idx]
    test_mask = y_test[idx]
    
    # Make prediction
    test_pred = model.predict(test_img[np.newaxis, ...])
    test_pred_binary = (test_pred > 0.5).astype(np.uint8)
    
    # Create figure
    fig, (ax1, ax2, ax3) = plt.subplots(1, 3, figsize=(15, 5))
    
    # Original image
    ax1.imshow(test_img[..., 0], cmap='gray')
    ax1.set_title('Original Image')
    ax1.axis('off')
    
    # Ground truth mask
    ax2.imshow(test_mask[..., 0], cmap='gray')
    ax2.set_title('Ground Truth Mask')
    ax2.axis('off')
    
    # Predicted mask
    pred_display = ax3.imshow(test_pred[0, ..., 0], cmap='magma')
    ax3.set_title('Predicted Mask')
    ax3.axis('off')
    
    # Add colorbar
    plt.colorbar(pred_display, ax=ax3)
    
    plt.tight_layout()
    plt.show()
    
    # Convert masks to float32 for metric calculation
    test_mask_float = tf.cast(test_mask, tf.float32)
    test_pred_float = tf.cast(test_pred, tf.float32)
    
    # Calculate metrics for this prediction
    dice = dice_coefficient(
        test_mask_float[np.newaxis, ...], 
        test_pred_float
    ).numpy()
    
    iou = iou_metric(
        test_mask_float[np.newaxis, ...], 
        test_pred_float
    ).numpy()
    
    print(f"Dice coefficient for this prediction: {dice:.4f}")
    print(f"IoU for this prediction: {iou:.4f}")

# Update the metric functions to ensure type consistency
def dice_coefficient(y_true, y_pred, smooth=1.0):
    # Ensure inputs are float32
    y_true = tf.cast(y_true, tf.float32)
    y_pred = tf.cast(y_pred, tf.float32)
    
    y_true_f = tf.keras.backend.flatten(y_true)
    y_pred_f = tf.keras.backend.flatten(y_pred)
    intersection = tf.keras.backend.sum(y_true_f * y_pred_f)
    return (2. * intersection + smooth) / (tf.keras.backend.sum(y_true_f) + tf.keras.backend.sum(y_pred_f) + smooth)

def iou_metric(y_true, y_pred, smooth=1.0):
    # Ensure inputs are float32
    y_true = tf.cast(y_true, tf.float32)
    y_pred = tf.cast(y_pred, tf.float32)
    
    intersection = tf.keras.backend.sum(tf.keras.backend.abs(y_true * y_pred), axis=[1, 2, 3])
    union = tf.keras.backend.sum(y_true, axis=[1, 2, 3]) + tf.keras.backend.sum(y_pred, axis=[1, 2, 3]) - intersection
    iou = tf.keras.backend.mean((intersection + smooth) / (union + smooth), axis=0)
    return iou

# Visualize a random prediction
visualize_prediction(unet_fpn_model, X_test, y_test)
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 3s 3s/step
# Dice coefficient for this prediction: 0.8715
# IoU for this prediction: 0.7723

# %%
def visualize_prediction(model, X_test, y_test, idx=None):
    if idx is None:
        idx = np.random.randint(0, len(X_test))
    
    test_img = X_test[idx]
    test_mask = y_test[idx]
    
    # Make prediction
    test_pred = model.predict(test_img[np.newaxis, ...])
    test_pred_binary = (test_pred > 0.5).astype(np.uint8)
    
    # Create figure
    fig, (ax1, ax2, ax3) = plt.subplots(1, 3, figsize=(15, 5))
    
    # Original image
    ax1.imshow(test_img[..., 0], cmap='gray')
    ax1.set_title('Original Image')
    ax1.axis('off')
    
    # Ground truth mask
    ax2.imshow(test_mask[..., 0], cmap='gray')
    ax2.set_title('Ground Truth Mask')
    ax2.axis('off')
    
    # Predicted mask
    pred_display = ax3.imshow(test_pred[0, ..., 0], cmap='magma')
    ax3.set_title('Predicted Mask')
    ax3.axis('off')
    
    # Add colorbar
    plt.colorbar(pred_display, ax=ax3)
    
    plt.tight_layout()
    plt.show()
    
    # Convert masks to float32 for metric calculation
    test_mask_float = tf.cast(test_mask, tf.float32)
    test_pred_float = tf.cast(test_pred, tf.float32)
    
    # Calculate metrics for this prediction
    dice = dice_coefficient(
        test_mask_float[np.newaxis, ...], 
        test_pred_float
    ).numpy()
    
    iou = iou_metric(
        test_mask_float[np.newaxis, ...], 
        test_pred_float
    ).numpy()
    
    print(f"Dice coefficient for this prediction: {dice:.4f}")
    print(f"IoU for this prediction: {iou:.4f}")

# Update the metric functions to ensure type consistency
def dice_coefficient(y_true, y_pred, smooth=1.0):
    # Ensure inputs are float32
    y_true = tf.cast(y_true, tf.float32)
    y_pred = tf.cast(y_pred, tf.float32)
    
    y_true_f = tf.keras.backend.flatten(y_true)
    y_pred_f = tf.keras.backend.flatten(y_pred)
    intersection = tf.keras.backend.sum(y_true_f * y_pred_f)
    return (2. * intersection + smooth) / (tf.keras.backend.sum(y_true_f) + tf.keras.backend.sum(y_pred_f) + smooth)

def iou_metric(y_true, y_pred, smooth=1.0):
    # Ensure inputs are float32
    y_true = tf.cast(y_true, tf.float32)
    y_pred = tf.cast(y_pred, tf.float32)
    
    intersection = tf.keras.backend.sum(tf.keras.backend.abs(y_true * y_pred), axis=[1, 2, 3])
    union = tf.keras.backend.sum(y_true, axis=[1, 2, 3]) + tf.keras.backend.sum(y_pred, axis=[1, 2, 3]) - intersection
    iou = tf.keras.backend.mean((intersection + smooth) / (union + smooth), axis=0)
    return iou

# Visualize a random prediction
visualize_prediction(unet_fpn_model, X_test, y_test)
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step
# Dice coefficient for this prediction: 0.9556
# IoU for this prediction: 0.9150

# %% [markdown]
# # Save Model

# %%
unet_fpn_model.save('UNet_fpn_model.h5')

# %%
def visualize_prediction(model, X_test, y_test, idx):
    if idx is None:
        raise ValueError("Index of the sample image must be provided.")
    
    test_img = X_test[idx]
    test_mask = y_test[idx]
    
    # Make prediction
    test_pred = model.predict(test_img[np.newaxis, ...])
    test_pred_binary = (test_pred > 0.5).astype(np.uint8)
    
    # Create figure
    fig, (ax1, ax2, ax3) = plt.subplots(1, 3, figsize=(15, 5))
    
    # Original image
    ax1.imshow(test_img[..., 0], cmap='gray')
    ax1.set_title('Original Image')
    ax1.axis('off')
    
    # Ground truth mask
    ax2.imshow(test_mask[..., 0], cmap='gray')
    ax2.set_title('Ground Truth Mask')
    ax2.axis('off')
    
    # Predicted mask
    pred_display = ax3.imshow(test_pred[0, ..., 0], cmap='magma')
    ax3.set_title('Predicted Mask')
    ax3.axis('off')
    
    # Add colorbar
    plt.colorbar(pred_display, ax=ax3)
    
    plt.tight_layout()
    plt.show()
    
    # Convert masks to float32 for metric calculation
    test_mask_float = tf.cast(test_mask, tf.float32)
    test_pred_float = tf.cast(test_pred, tf.float32)
    
    # Calculate metrics for this prediction
    dice = dice_coefficient(
        test_mask_float[np.newaxis, ...], 
        test_pred_float
    ).numpy()
    
    iou = iou_metric(
        test_mask_float[np.newaxis, ...], 
        test_pred_float
    ).numpy()
    
    print(f"Dice coefficient for this prediction: {dice:.4f}")
    print(f"IoU for this prediction: {iou:.4f}")

# Update the metric functions to ensure type consistency
def dice_coefficient(y_true, y_pred, smooth=1.0):
    # Ensure inputs are float32
    y_true = tf.cast(y_true, tf.float32)
    y_pred = tf.cast(y_pred, tf.float32)
    
    y_true_f = tf.keras.backend.flatten(y_true)
    y_pred_f = tf.keras.backend.flatten(y_pred)
    intersection = tf.keras.backend.sum(y_true_f * y_pred_f)
    return (2. * intersection + smooth) / (tf.keras.backend.sum(y_true_f) + tf.keras.backend.sum(y_pred_f) + smooth)

def iou_metric(y_true, y_pred, smooth=1.0):
    # Ensure inputs are float32
    y_true = tf.cast(y_true, tf.float32)
    y_pred = tf.cast(y_pred, tf.float32)
    
    intersection = tf.keras.backend.sum(tf.keras.backend.abs(y_true * y_pred), axis=[1, 2, 3])
    union = tf.keras.backend.sum(y_true, axis=[1, 2, 3]) + tf.keras.backend.sum(y_pred, axis=[1, 2, 3]) - intersection
    iou = tf.keras.backend.mean((intersection + smooth) / (union + smooth), axis=0)
    return iou

# Visualize a specific prediction
visualize_prediction(unet_fpn_model, X_test, y_test, idx=80)
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# Dice coefficient for this prediction: 0.8048
# IoU for this prediction: 0.6734
